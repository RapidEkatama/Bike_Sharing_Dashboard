# %%
#Get the necessary library
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
#This is a code that is you want to get the .csv data from Google Drive
#If from local drive you can skip this

# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

downloaded1 = drive.CreateFile({'id':'1HEFoDqdyibTMTc5KxkkCvep7pukA6PUl'})
downloaded2 = drive.CreateFile({'id':'1I9VmMX9mrbRB4_qqM0OWblm007J8ltUn'})
downloaded1.GetContentFile('hour.csv')
downloaded2.GetContentFile('day.csv')

# %%
#Get the csv into DataFrame
df_day = pd.read_csv('day.csv')
df_hour = pd.read_csv('hour.csv')

# %%
#Check the dataframe
df_day
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
#Check the dataframe
df_hour
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 0            1  2011-01-01       1   0     1   0        0        6
# 1            2  2011-01-01       1   0     1   1        0        6
# 2            3  2011-01-01       1   0     1   2        0        6
# 3            4  2011-01-01       1   0     1   3        0        6
# 4            5  2011-01-01       1   0     1   4        0        6
# ...        ...         ...     ...  ..   ...  ..      ...      ...
# 17374    17375  2012-12-31       1   1    12  19        0        1
# 17375    17376  2012-12-31       1   1    12  20        0        1
# 17376    17377  2012-12-31       1   1    12  21        0        1
# 17377    17378  2012-12-31       1   1    12  22        0        1
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 0               0           1  0.24  0.2879  0.81     0.0000       3
# ...

# %%
#check the data information
df_day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
#check the data information
df_hour.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
#Copying the original dataset
df_day_copy = df_day.copy()
df_hour_copy = df_hour.copy()

# %%
#Make a dictionary to change the categorical value from numeric into string 
Season_Map = {1:'Spring',
              2:'Summer',
              3:'Fall',
              4:'Winter'}

#Make a variable contain some columns
Day_Season = df_day_copy[['season','weathersit','temp','atemp','hum','windspeed']]
#Mapping the 'season' from numeric into string
Day_Season['season'] = Day_Season['season'].map(Season_Map)
Day_Season = Day_Season.groupby(['season']).mean()

Day_Season
# Out:
# <ipython-input-9-ac282365750b>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Day_Season['season'] = Day_Season['season'].map(Season_Map)
#         weathersit      temp     atemp       hum  windspeed
# season
# Fall      1.297872  0.706309  0.655898  0.633482   0.172095
# Spring    1.408840  0.297748  0.296914  0.582903   0.214537
# Summer    1.402174  0.544405  0.520307  0.626948   0.203507
# Winter    1.477528  0.422906  0.415539  0.668719   0.171995

# %% [markdown]
# From table above, we can see that each season has the own of characteristic. From `Fall` Season, it has the higher temperature (in Celcius degree). In `Spring` Season slightly has the lower humidity which is affect on more dry humidity that the other season.

# %%
# Get the mean each customer in fall season
Fall_Day = df_day_copy[df_day_copy['season'] == 3]
Fall_Day_C = Fall_Day['casual'].mean().round(1)
Fall_Day_R = Fall_Day['registered'].mean().round(1)
Fall_Day_T = Fall_Day['cnt'].mean().round(1)

# Get the mean each customer in spring season
Spring_Day = df_day_copy[df_day_copy['season'] == 1]
Spring_Day_C = Spring_Day['casual'].mean().round(1)
Spring_Day_R = Spring_Day['registered'].mean().round(1)
Spring_Day_T = Spring_Day['cnt'].mean().round(1)

# Show the table contain of mean each group of customer
A = pd.DataFrame({'Season':['Fall','Spring','Mean Total'],
                  'Casual':[Fall_Day_C,Spring_Day_C,df_day_copy['casual'].mean().round(1)],
                  'Registered':[Fall_Day_R,Spring_Day_R,df_day_copy['registered'].mean().round(1)],
                  'Total Cust':[Fall_Day_T,Spring_Day_T,df_day_copy['cnt'].mean().round(1)],
                  })
A = A.style.set_caption('Table Mean of Customer Based on Differences in Temperature and Humidity Conditions')
A
# Out:
# <style type="text/css">
# </style>
# <table id="T_b9774" class="dataframe">
#   <caption>Table Mean of Customer Based on Differences in Temperature and Humidity Conditions</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b9774_level0_col0" class="col_heading level0 col0" >Season</th>
#       <th id="T_b9774_level0_col1" class="col_heading level0 col1" >Casual</th>
#       <th id="T_b9774_level0_col2" class="col_heading level0 col2" >Registered</th>
#       <th id="T_b9774_level0_col3" class="col_heading level0 col3" >Total Cust</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9774_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b9774_row0_col0" class="data row0 col0" >Fall</td>
#       <td id="T_b9774_row0_col1" class="data row0 col1" >1202.600000</td>
#       <td id="T_b9774_row0_col2" class="data row0 col2" >4441.700000</td>
# ...

# %% [markdown]
# Continuing the previous statement, from the different `Fall` and `Spring` season conditions compared to other seasons, it was concluded that in `Fall` Season has the higher casual and registered users and `Spring` has the lowest.

# %%
#make a dictionary to change 'weekday' value from numeric into string
Day_Map = {0:'Sunday',
           1:'Monday',
           2:'Tuesday',
           3:'Wednesday',
           4:'Thursday',
           5:'Friday',
           6:'Saturday'}

#Mapping the dictionary into 'weekday' columns
df_day_copy['weekday'] = df_day_copy['weekday'].map(Day_Map)
df_day_copy['season'] = df_day_copy['season'].map(Season_Map)
df_day_copy
# Out:
#      instant      dteday  season  yr  mnth  holiday    weekday  workingday  \
# 0          1  2011-01-01  Spring   0     1        0   Saturday           0
# 1          2  2011-01-02  Spring   0     1        0     Sunday           0
# 2          3  2011-01-03  Spring   0     1        0     Monday           1
# 3          4  2011-01-04  Spring   0     1        0    Tuesday           1
# 4          5  2011-01-05  Spring   0     1        0  Wednesday           1
# ..       ...         ...     ...  ..   ...      ...        ...         ...
# 726      727  2012-12-27  Spring   1    12        0   Thursday           1
# 727      728  2012-12-28  Spring   1    12        0     Friday           1
# 728      729  2012-12-29  Spring   1    12        0   Saturday           0
# 729      730  2012-12-30  Spring   1    12        0     Sunday           0
# 730      731  2012-12-31  Spring   1    12        0     Monday           1
#
# ...

# %%
#make a line plot from 'weekday' and 'cnt' (total users)
plt.figure(figsize=(8,5))
sns.lineplot(data=df_day_copy, x='weekday', y='cnt', errorbar=None)
plt.title('Chart of Total Users in One Year each Weekday')
# Out:
# Text(0.5, 1.0, 'Chart of Total Users in One Year each Weekday')

# %% [markdown]
# From chart above, we can get a conclusion that in `Sunday` has the lowest total user, and in `Friday` it has the highest total user. With that information we can make a plan that keep an eye on customer in weekends and make a trial and error plan or evaluation plan in `Sunday` because in that day has the lowest Total Users and first weekday too.

# %%
#make a line plot from 'weekday' and 'cnt' (total users), and separate with 'season' category
plt.figure(figsize=(8,5))
sns.lineplot(data=df_day_copy, x='weekday', y='cnt', hue='season', errorbar=None)
plt.title('Chart of Total Users in One Year each Weekday Group by Season')
# Out:
# Text(0.5, 1.0, 'Chart of Total Users in One Year each Weekday Group by Season')

# %% [markdown]
# From chart above, we can conclude that in `Spring` has the lowest total users in any days. `Fall` season has the highest total users, and a slightly different in `Summer` and `Winter` season. On that chart we can make a evaluation because based on situation, how can be a bike sharing users in `Winter` season higher than users in `Spring` season. We can check the on several factors on public, such as main activities, work habbits, their economy, and geological condition each season.
